# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import pyplot
from numpy import random


img= image.imread("/home/idsd/Bureau/IDSD2/G2/Machine-learning/dog.jpg")
print(img.dtype)
print(img.shape)

pyplot.imshow(img)
pyplot.show()
# Out:
# uint8
# (768, 768, 3)

# %%
# 1
imgcopy=img[150:450,230:490].copy()
print(imgcopy.shape)
pyplot.imshow(imgcopy)
pyplot.show()
# Out:
# (300, 260, 3)

# %%
# 2
imgcopy[np.random.randint(444,size=imgcopy.shape[0]),np.random.randint(444,size=imgcopy.shape[1])]=0
pyplot.imshow(imgcopy)
pyplot.show()
#salt=np.zeros((300,260,3))
#pepper=np.full((300,260,3),255)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_38301/1444147851.py in <module>
#       1 # 2
#       2 mask=np.array([np.zeros(imgcopy.shape),np.full(imgcopy.shape,255)])
# ----> 3 imgcopy[np.random.randint(444,size=imgcopy.shape[0]),np.random.randint(444,size=imgcopy.shape[1])]=0
#       4 pyplot.imshow(imgcopy)
#       5 pyplot.show()
#
# IndexError: shape mismatch: indexing arrays could not be broadcast together with shapes (300,) (260,)
